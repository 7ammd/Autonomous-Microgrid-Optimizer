# %%
# !pip install stable_baselines3
# Out:
# Requirement already satisfied: stable_baselines3 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (2.8.0)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from stable_baselines3) (1.2.3)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from stable_baselines3) (2.4.4)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from stable_baselines3) (2.11.0)
# Requirement already satisfied: cloudpickle in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from stable_baselines3) (3.1.2)
# Requirement already satisfied: pandas in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from stable_baselines3) (3.0.2)
# Requirement already satisfied: matplotlib in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from stable_baselines3) (3.10.8)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable_baselines3) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.25.2)
# Requirement already satisfied: setuptools<82 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from torch<3.0,>=2.3->stable_baselines3) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from torch<3.0,>=2.3->stable_baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from torch<3.0,>=2.3->stable_baselines3) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from matplotlib->stable_baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from matplotlib->stable_baselines3) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from matplotlib->stable_baselines3) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from matplotlib->stable_baselines3) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from matplotlib->stable_baselines3) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from matplotlib->stable_baselines3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from matplotlib->stable_baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: tzdata in c:\users\equipo\desktop\newteamproject\proj2\lib\site-packages (from pandas->stable_baselines3) (2026.1)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from stable_baselines3 import PPO
from microgrid_env import MicroGridEnv
import time

print("1. Loading the MicroGrid Physics Engine...")
env = MicroGridEnv()

print("2. Initializing the PyTorch Neural Network (PPO)...")
model = PPO("MlpPolicy", env, verbose=1, learning_rate=0.0003)

print("3. Commencing AI Training (300,000 steps)...")
start_time = time.time()
model.learn(total_timesteps=300000)
end_time = time.time()

print(f"Training Complete! Time elapsed: {round(end_time - start_time, 1)} seconds.")

print("4. Saving the Brain...")
model.save("ppo_smart_microgrid")
print("Success. Model saved as 'ppo_smart_microgrid.zip'")
# Out:
# 1. Loading the MicroGrid Physics Engine...
# 2. Initializing the PyTorch Neural Network (PPO)...
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 3. Commencing AI Training (300,000 steps)...
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 720       |
# |    ep_rew_mean     | -4.35e+03 |
# | time/              |           |
# |    fps             | 1518      |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -2.76e+03    |
# | time/                   |              |
# |    fps                  | 1013         |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0092693325 |
# |    clip_fraction        | 0.0973       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000638    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.4e+03      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0139      |
# |    std                  | 0.992        |
# |    value_loss           | 1.26e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 720        |
# |    ep_rew_mean          | -2.08e+03  |
# | time/                   |            |
# |    fps                  | 930        |
# |    iterations           | 3          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00647558 |
# |    clip_fraction        | 0.0759     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | -0.0115    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 789        |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00905   |
# |    std                  | 1          |
# |    value_loss           | 1.93e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.78e+03    |
# | time/                   |              |
# |    fps                  | 890          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0061664144 |
# |    clip_fraction        | 0.0561       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0119      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 79.8         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00405     |
# |    std                  | 0.983        |
# |    value_loss           | 234          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.6e+03     |
# | time/                   |              |
# |    fps                  | 884          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0032917769 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.00604     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.1         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00464     |
# |    std                  | 0.971        |
# |    value_loss           | 299          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.47e+03    |
# | time/                   |              |
# |    fps                  | 952          |
# |    iterations           | 6            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0042722654 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.00348     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.6         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00213     |
# |    std                  | 0.985        |
# |    value_loss           | 166          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -1.41e+03   |
# | time/                   |             |
# |    fps                  | 1000        |
# |    iterations           | 7           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005251904 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -0.00151    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00162    |
# |    std                  | 0.972       |
# |    value_loss           | 139         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.34e+03    |
# | time/                   |              |
# |    fps                  | 1046         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0033306296 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.00122     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.1         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00154     |
# |    std                  | 0.968        |
# |    value_loss           | 118          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -1.29e+03   |
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004569932 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.000638   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00297    |
# |    std                  | 0.958       |
# |    value_loss           | 113         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 720        |
# |    ep_rew_mean          | -1.25e+03  |
# | time/                   |            |
# |    fps                  | 1105       |
# |    iterations           | 10         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00467792 |
# |    clip_fraction        | 0.0397     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.000585  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.6       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.000915  |
# |    std                  | 0.944      |
# |    value_loss           | 104        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 1134         |
# |    iterations           | 11           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0052275476 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000695    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75.7         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00272     |
# |    std                  | 0.919        |
# |    value_loss           | 158          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 720       |
# |    ep_rew_mean          | -1.19e+03 |
# | time/                   |           |
# |    fps                  | 1152      |
# |    iterations           | 12        |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0191576 |
# |    clip_fraction        | 0.0583    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.34     |
# |    explained_variance   | -0.000171 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 49.6      |
# |    n_updates            | 110       |
# |    policy_gradient_loss | 0.000219  |
# |    std                  | 0.932     |
# |    value_loss           | 99        |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 1172         |
# |    iterations           | 13           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0066641136 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000118    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.7         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.000912     |
# |    std                  | 0.928        |
# |    value_loss           | 103          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -1.15e+03   |
# | time/                   |             |
# |    fps                  | 1185        |
# |    iterations           | 14          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015684512 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -7.24e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.3        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00376    |
# |    std                  | 0.903       |
# |    value_loss           | 74.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -1.13e+03   |
# | time/                   |             |
# |    fps                  | 1192        |
# |    iterations           | 15          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011601643 |
# |    clip_fraction        | 0.0724      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -8.67e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52          |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.0012      |
# |    std                  | 0.893       |
# |    value_loss           | 111         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -1.12e+03   |
# | time/                   |             |
# |    fps                  | 1212        |
# |    iterations           | 16          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.003572457 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -2.48e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 9.06e-05    |
# |    std                  | 0.877       |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -1.1e+03    |
# | time/                   |             |
# |    fps                  | 1219        |
# |    iterations           | 17          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008671109 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -2.03e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.5        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0018      |
# |    std                  | 0.877       |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 1226        |
# |    iterations           | 18          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013428543 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -2.79e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 113         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000887   |
# |    std                  | 0.86        |
# |    value_loss           | 135         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 1240         |
# |    iterations           | 19           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0065156803 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -1.11e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33           |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.00059      |
# |    std                  | 0.842        |
# |    value_loss           | 129          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 1246         |
# |    iterations           | 20           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0068851053 |
# |    clip_fraction        | 0.0695       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -1.62e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.8         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.838        |
# |    value_loss           | 136          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -1.06e+03   |
# | time/                   |             |
# |    fps                  | 1250        |
# |    iterations           | 21          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004586949 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -6.08e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.8        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.000437   |
# |    std                  | 0.834       |
# |    value_loss           | 93.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.05e+03    |
# | time/                   |              |
# |    fps                  | 1265         |
# |    iterations           | 22           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0035331221 |
# |    clip_fraction        | 0.08         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -6.79e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.3         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00159     |
# |    std                  | 0.813        |
# |    value_loss           | 156          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.05e+03    |
# | time/                   |              |
# |    fps                  | 1236         |
# |    iterations           | 23           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0107784895 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | -1.07e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 146          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000881    |
# |    std                  | 0.806        |
# |    value_loss           | 136          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.04e+03    |
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 24           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0060952976 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | -4.29e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.2         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00185     |
# |    std                  | 0.8          |
# |    value_loss           | 157          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.03e+03    |
# | time/                   |              |
# |    fps                  | 1179         |
# |    iterations           | 25           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0032972065 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | -1.91e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.2         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000556    |
# |    std                  | 0.786        |
# |    value_loss           | 136          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.03e+03    |
# | time/                   |              |
# |    fps                  | 1155         |
# |    iterations           | 26           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0069589987 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | -9.54e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.7         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00428     |
# |    std                  | 0.774        |
# |    value_loss           | 142          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 720        |
# |    ep_rew_mean          | -1.02e+03  |
# | time/                   |            |
# |    fps                  | 1133       |
# |    iterations           | 27         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00792373 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | -1.31e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.7       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00295   |
# |    std                  | 0.758      |
# |    value_loss           | 96.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -1.02e+03   |
# | time/                   |             |
# |    fps                  | 1114        |
# |    iterations           | 28          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.007990334 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | -1.67e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.3        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00168    |
# |    std                  | 0.745       |
# |    value_loss           | 149         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.01e+03    |
# | time/                   |              |
# |    fps                  | 1096         |
# |    iterations           | 29           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0031435606 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | -1.43e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 99.2         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.0013       |
# |    std                  | 0.749        |
# |    value_loss           | 149          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1.01e+03    |
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 30           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0048737726 |
# |    clip_fraction        | 0.0638       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | -9.54e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 98.2         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.000332     |
# |    std                  | 0.752        |
# |    value_loss           | 147          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -1e+03       |
# | time/                   |              |
# |    fps                  | 1067         |
# |    iterations           | 31           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0047456054 |
# |    clip_fraction        | 0.0696       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 144          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 9.63e-05     |
# |    std                  | 0.737        |
# |    value_loss           | 140          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -997        |
# | time/                   |             |
# |    fps                  | 1054        |
# |    iterations           | 32          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.014085213 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | -1.07e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.7        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00157    |
# |    std                  | 0.732       |
# |    value_loss           | 146         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -994         |
# | time/                   |              |
# |    fps                  | 1044         |
# |    iterations           | 33           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0030410313 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46           |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.000415     |
# |    std                  | 0.719        |
# |    value_loss           | 141          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -990         |
# | time/                   |              |
# |    fps                  | 1035         |
# |    iterations           | 34           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0012935037 |
# |    clip_fraction        | 0.0734       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -9.54e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 126          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.00267      |
# |    std                  | 0.714        |
# |    value_loss           | 98.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -987         |
# | time/                   |              |
# |    fps                  | 1025         |
# |    iterations           | 35           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0041503534 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.1         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000177    |
# |    std                  | 0.706        |
# |    value_loss           | 145          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -917        |
# | time/                   |             |
# |    fps                  | 1016        |
# |    iterations           | 36          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.016431376 |
# |    clip_fraction        | 0.0845      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 178         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00149    |
# |    std                  | 0.695       |
# |    value_loss           | 143         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -891        |
# | time/                   |             |
# |    fps                  | 1010        |
# |    iterations           | 37          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008313466 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -5.96e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 121         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.000197    |
# |    std                  | 0.688       |
# |    value_loss           | 151         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -889         |
# | time/                   |              |
# |    fps                  | 1002         |
# |    iterations           | 38           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0032597273 |
# |    clip_fraction        | 0.0827       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.2         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.000466     |
# |    std                  | 0.693        |
# |    value_loss           | 140          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -887        |
# | time/                   |             |
# |    fps                  | 995         |
# |    iterations           | 39          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.003112941 |
# |    clip_fraction        | 0.0849      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 202         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0012     |
# |    std                  | 0.68        |
# |    value_loss           | 140         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -884        |
# | time/                   |             |
# |    fps                  | 988         |
# |    iterations           | 40          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012350479 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 8.81e-05    |
# |    std                  | 0.675       |
# |    value_loss           | 95.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -882         |
# | time/                   |              |
# |    fps                  | 982          |
# |    iterations           | 41           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0039691585 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.97         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.000523     |
# |    std                  | 0.666        |
# |    value_loss           | 143          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -881         |
# | time/                   |              |
# |    fps                  | 977          |
# |    iterations           | 42           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0047285426 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 222          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000264     |
# |    std                  | 0.662        |
# |    value_loss           | 137          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -880        |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 43          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008042879 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 113         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.000819   |
# |    std                  | 0.651       |
# |    value_loss           | 144         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -879        |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 44          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.003521664 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.983      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00193     |
# |    std                  | 0.642       |
# |    value_loss           | 140         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 720       |
# |    ep_rew_mean          | -877      |
# | time/                   |           |
# |    fps                  | 958       |
# |    iterations           | 45        |
# |    time_elapsed         | 96        |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.005188  |
# |    clip_fraction        | 0.0609    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.973    |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 69.7      |
# |    n_updates            | 440       |
# |    policy_gradient_loss | 5.89e-05  |
# |    std                  | 0.64      |
# |    value_loss           | 144       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -876        |
# | time/                   |             |
# |    fps                  | 955         |
# |    iterations           | 46          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005033992 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 124         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00172    |
# |    std                  | 0.632       |
# |    value_loss           | 140         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -875        |
# | time/                   |             |
# |    fps                  | 949         |
# |    iterations           | 47          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011430543 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.9        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00216    |
# |    std                  | 0.627       |
# |    value_loss           | 94.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -874        |
# | time/                   |             |
# |    fps                  | 943         |
# |    iterations           | 48          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010230932 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 74.5        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00125    |
# |    std                  | 0.624       |
# |    value_loss           | 143         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -873         |
# | time/                   |              |
# |    fps                  | 937          |
# |    iterations           | 49           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0032464173 |
# |    clip_fraction        | 0.0916       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.943       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.2         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.000528     |
# |    std                  | 0.617        |
# |    value_loss           | 141          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -872        |
# | time/                   |             |
# |    fps                  | 935         |
# |    iterations           | 50          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007446086 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.933      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 128         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0024     |
# |    std                  | 0.614       |
# |    value_loss           | 144         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -872         |
# | time/                   |              |
# |    fps                  | 931          |
# |    iterations           | 51           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0038417426 |
# |    clip_fraction        | 0.0639       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.7         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000289    |
# |    std                  | 0.607        |
# |    value_loss           | 140          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -872        |
# | time/                   |             |
# |    fps                  | 927         |
# |    iterations           | 52          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008999364 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.5        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 3.28e-05    |
# ...
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -848         |
# | time/                   |              |
# |    fps                  | 931          |
# |    iterations           | 131          |
# |    time_elapsed         | 288          |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0062615117 |
# |    clip_fraction        | 0.0599       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0381      |
# |    explained_variance   | 0.00707      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 111          |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | 0.00098      |
# |    std                  | 0.249        |
# |    value_loss           | 135          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -848        |
# | time/                   |             |
# |    fps                  | 930         |
# |    iterations           | 132         |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.007309993 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0194     |
# |    explained_variance   | 0.0108      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.8        |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.00465    |
# |    std                  | 0.244       |
# |    value_loss           | 137         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -848        |
# | time/                   |             |
# |    fps                  | 928         |
# |    iterations           | 133         |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.008060738 |
# |    clip_fraction        | 0.0808      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00886    |
# |    explained_variance   | 0.0104      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.9        |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.000919   |
# |    std                  | 0.245       |
# |    value_loss           | 136         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -848         |
# | time/                   |              |
# |    fps                  | 927          |
# |    iterations           | 134          |
# |    time_elapsed         | 296          |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0032227268 |
# |    clip_fraction        | 0.0807       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00381     |
# |    explained_variance   | 0.0108       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 115          |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.000125    |
# |    std                  | 0.241        |
# |    value_loss           | 138          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -848         |
# | time/                   |              |
# |    fps                  | 928          |
# |    iterations           | 135          |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0085024405 |
# |    clip_fraction        | 0.0835       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.00697      |
# |    explained_variance   | 0.012        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 111          |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | 0.00113      |
# |    std                  | 0.24         |
# |    value_loss           | 136          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -848        |
# | time/                   |             |
# |    fps                  | 931         |
# |    iterations           | 136         |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.005441551 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0106      |
# |    explained_variance   | 0.011       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 134         |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | 0.000936    |
# |    std                  | 0.239       |
# |    value_loss           | 138         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -849        |
# | time/                   |             |
# |    fps                  | 933         |
# |    iterations           | 137         |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.004623669 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0171      |
# |    explained_variance   | 0.00817     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.4        |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.00166    |
# |    std                  | 0.237       |
# |    value_loss           | 97.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -849         |
# | time/                   |              |
# |    fps                  | 935          |
# |    iterations           | 138          |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0057218783 |
# |    clip_fraction        | 0.0978       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.0264       |
# |    explained_variance   | 0.00813      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 134          |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00199     |
# |    std                  | 0.234        |
# |    value_loss           | 141          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -849        |
# | time/                   |             |
# |    fps                  | 938         |
# |    iterations           | 139         |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.006709099 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0317      |
# |    explained_variance   | 0.0095      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 78.8        |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | 0.0002      |
# |    std                  | 0.235       |
# |    value_loss           | 142         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -849        |
# | time/                   |             |
# |    fps                  | 940         |
# |    iterations           | 140         |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.009828107 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0379      |
# |    explained_variance   | 0.00833     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | 0.00136     |
# |    std                  | 0.231       |
# |    value_loss           | 143         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -849        |
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 141         |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.010571259 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0562      |
# |    explained_variance   | 0.00884     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.8        |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | -0.00019    |
# |    std                  | 0.227       |
# |    value_loss           | 136         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -849        |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 142         |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.008907927 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0713      |
# |    explained_variance   | 0.00919     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.6        |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.000464   |
# |    std                  | 0.224       |
# |    value_loss           | 142         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -849        |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 143         |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.012907222 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0785      |
# |    explained_variance   | 0.00997     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.27        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | 0.00354     |
# |    std                  | 0.224       |
# |    value_loss           | 94.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | -849         |
# | time/                   |              |
# |    fps                  | 943          |
# |    iterations           | 144          |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0034959926 |
# |    clip_fraction        | 0.0833       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.0828       |
# |    explained_variance   | 0.00852      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.3         |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | 0.000193     |
# |    std                  | 0.223        |
# |    value_loss           | 137          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -849        |
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 145         |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.009741157 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.092       |
# |    explained_variance   | 0.00955     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | 0.00109     |
# |    std                  | 0.22        |
# |    value_loss           | 140         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -848        |
# | time/                   |             |
# |    fps                  | 939         |
# |    iterations           | 146         |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.009001021 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.111       |
# |    explained_variance   | 0.00934     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.98        |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | -0.00336    |
# |    std                  | 0.214       |
# |    value_loss           | 137         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 720         |
# |    ep_rew_mean          | -848        |
# | time/                   |             |
# |    fps                  | 939         |
# |    iterations           | 147         |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.006004058 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.125       |
# |    explained_variance   | 0.0108      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | 0.000484    |
# |    std                  | 0.213       |
# |    value_loss           | 136         |
# -----------------------------------------
# Training Complete! Time elapsed: 321.2 seconds.
# 4. Saving the Brain...
# Success. Model saved as 'ppo_smart_microgrid.zip'
